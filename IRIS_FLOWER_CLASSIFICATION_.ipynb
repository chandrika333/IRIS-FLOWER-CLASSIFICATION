# %%
data=pd.read_csv('/content/archive (6).zip')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.sample(15)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 105  106            7.6           3.0            6.6           2.1
# 97    98            6.2           2.9            4.3           1.3
# 85    86            6.0           3.4            4.5           1.6
# 112  113            6.8           3.0            5.5           2.1
# 126  127            6.2           2.8            4.8           1.8
# 24    25            4.8           3.4            1.9           0.2
# 127  128            6.1           3.0            4.9           1.8
# 78    79            6.0           2.9            4.5           1.5
# 50    51            7.0           3.2            4.7           1.4
# 77    78            6.7           3.0            5.0           1.7
# 137  138            6.4           3.1            5.5           1.8
# 142  143            5.8           2.7            5.1           1.9
# 39    40            5.1           3.4            1.5           0.2
# ...

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df=data.copy()

# %%
df.drop(['Id'], axis=1, inplace=True)

# %%
sns.countplot(x='Species', data=df, palette='Set2')
# Out:
# <ipython-input-12-3e67a67ddabb>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Species', data=df, palette='Set2')
# <Axes: xlabel='Species', ylabel='count'>

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.groupby(["Species"], as_index=False)["SepalLengthCm"].mean()
# Out:
#            Species  SepalLengthCm
# 0      Iris-setosa          5.006
# 1  Iris-versicolor          5.936
# 2   Iris-virginica          6.588

# %%
mean_sepal_length = df.groupby("Species")["SepalLengthCm"].mean().reset_index()

# %%
# Define custom colors
colors = ["skyblue", "lightgreen", "salmon"]
# Plot using seaborn
sns.barplot(x="Species", y="SepalLengthCm", data=df, palette=colors)

# Add labels and title
plt.xlabel("Species")
plt.ylabel("Mean Sepal Length (cm)")
plt.title("Mean Sepal Length by Species")

# Show the plot
plt.show()
# Out:
# <ipython-input-16-90162a86608b>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Species", y="SepalLengthCm", data=df, palette=colors)

# %%
sns.boxplot(data=data, x="Species", y="SepalLengthCm", palette=colors)

# Add title and labels
plt.title("Box Plot of Sepal Length by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Length")

# Show plot
plt.show()
# Out:
# <ipython-input-17-51fd29971aaf>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="Species", y="SepalLengthCm", palette=colors)

# %%
df.groupby(["Species"], as_index=False)["SepalWidthCm"].mean()
# Out:
#            Species  SepalWidthCm
# 0      Iris-setosa         3.418
# 1  Iris-versicolor         2.770
# 2   Iris-virginica         2.974

# %%
mean_sepal_width=df.groupby(['Species'], as_index=False)['SepalWidthCm'].mean().reset_index()

# %%
# Plot using seaborn
sns.barplot(x="Species", y="SepalWidthCm", data=df, palette=colors)

# Add labels and title
plt.xlabel("Species")
plt.ylabel("Mean Sepal Width (cm)")
plt.title("Mean Sepal Width by Species")

# Show the plot
plt.show()
# Out:
# <ipython-input-20-adffaf4589e8>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Species", y="SepalWidthCm", data=df, palette=colors)

# %%
sns.boxplot(data=data, x="Species", y="SepalWidthCm", palette=colors)

# Add title and labels
plt.title("Box Plot of Sepal Width by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Width")

# Show plot
plt.show()
# Out:
# <ipython-input-21-0fabef2cb554>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="Species", y="SepalWidthCm", palette=colors)

# %%
df.groupby(["Species"], as_index=False)["PetalLengthCm"].mean()
# Out:
#            Species  PetalLengthCm
# 0      Iris-setosa          1.464
# 1  Iris-versicolor          4.260
# 2   Iris-virginica          5.552

# %%
mean_Petal_length=df.groupby(['Species'], as_index=False)['PetalLengthCm'].mean().reset_index()

# %%
sns.boxplot(data=data, x="Species", y="PetalLengthCm", palette=colors)

# Add title and labels
plt.title("Box Plot of Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length")

# Show plot
plt.show()
# Out:
# <ipython-input-24-3f162f71159e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="Species", y="PetalLengthCm", palette=colors)

# %%
df.groupby(["Species"], as_index=False)["PetalWidthCm"].mean()
# Out:
#            Species  PetalWidthCm
# 0      Iris-setosa         0.244
# 1  Iris-versicolor         1.326
# 2   Iris-virginica         2.026

# %%
mean_Petal_width=df.groupby(['Species'], as_index=False)['PetalWidthCm'].mean().reset_index()

# %%
sns.barplot(x='Species', y='PetalWidthCm', data=df, palette=colors)

# Add labels and title
plt.xlabel("Species")
plt.ylabel("Mean Petal Width (cm)")
plt.title("Mean Sepal Width by Species")

# Show the plot
plt.show()
# Out:
# <ipython-input-27-570a8ef6beb7>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Species', y='PetalWidthCm', data=df, palette=colors)

# %%
sns.boxplot(data=data, x="Species", y="PetalWidthCm", palette=colors)

# Add title and labels
plt.title("Box Plot of Petal Width by Species")
plt.xlabel("Species")
plt.ylabel("Petal Width")

# Show plot
plt.show()
# Out:
# <ipython-input-28-641771c3fdda>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="Species", y="PetalWidthCm", palette=colors)

# %%
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=df, palette='Set2')


# Add labels and title
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Scatter Plot of Petal Length vs. Petal Width')

# Show the plot
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df, palette='Set2')


# Add labels and title
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Scatter Plot of Sepal Length vs. Petal Width')

# Show the plot
plt.show()

# %%
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=df, kind='kde', shade=True, cmap='YlGnBu')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x='PetalLengthCm', y='PetalWidthCm', data=df, kind='kde', shade=True, cmap='YlGnBu')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.pairplot(data=df, hue="Species", markers=["o", "s", "D"])

# Add title
plt.subplots_adjust(top=0.95)
plt.suptitle("Pair Plot of Iris Dataset by Species")

# Show plot
plt.show()

# %%
dfcorr=df.drop(['Species'], axis=1).corr()

# %%
print(dfcorr)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(dfcorr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.clustermap(df.drop('Species', axis=1))

# %%
sns.kdeplot(df['SepalLengthCm'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(df['SepalWidthCm'])
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.kdeplot(df['PetalLengthCm'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(df['PetalWidthCm'])
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %%
# Create a figure and a grid of subplots with 2 rows and 2 columns
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# List of column names for the KDE plots
columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# Plot KDE plots for each column in its corresponding subplot
for i, column in enumerate(columns):
    sns.kdeplot(df[column], ax=axes[i])
    axes[i].set_title(f'KDE Plot of {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Density')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# %%
df1['coded_Species']=label_encoder.fit_transform(df1['Species'])
